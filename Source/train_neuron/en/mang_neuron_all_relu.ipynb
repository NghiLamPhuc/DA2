# %%
# Create your first MLP in Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
import os
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
np.random.seed(1)

# %%
dataset = np.loadtxt("train_en.txt")
# split into input (X) and output (Y) variables
X = dataset[:,0:300]
Y = dataset[:,300]
Y = keras.utils.to_categorical(Y, num_classes=13)

test_data = np.loadtxt("test_en.txt")
# split into input (X) and output (Y) variables
X_test = dataset[:,0:300]
Y_test = dataset[:,300]
Y_test = keras.utils.to_categorical(Y_test, num_classes=13)

# %%
# create model
model = Sequential()
model.add(Dense(100, input_dim=300, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(13, activation='relu'))
# Compile model
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                1313
# =================================================================
# Total params: 31,413
# Trainable params: 31,413
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model 1
history = model.fit(X, Y, epochs=50, batch_size=10,
          validation_data=(X_test, Y_test))
# evaluate the model
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Train on 31933 samples, validate on 31933 samples
# Epoch 1/50
# 31933/31933 [==============================] - 11s - loss: 2.5488 - acc: 0.1782 - val_loss: 2.2495 - val_acc: 0.2253
# Epoch 2/50
# 31933/31933 [==============================] - 11s - loss: 2.2544 - acc: 0.2128 - val_loss: 2.2206 - val_acc: 0.2386
# Epoch 3/50
# 31933/31933 [==============================] - 10s - loss: 2.2258 - acc: 0.2218 - val_loss: 2.2158 - val_acc: 0.2319
# Epoch 4/50
# 31933/31933 [==============================] - 10s - loss: 2.2157 - acc: 0.2249 - val_loss: 2.2126 - val_acc: 0.2418
# Epoch 5/50
# 31933/31933 [==============================] - 10s - loss: 2.2132 - acc: 0.2243 - val_loss: 2.2101 - val_acc: 0.2406
# Epoch 6/50
# 31933/31933 [==============================] - 10s - loss: 2.2099 - acc: 0.2286 - val_loss: 2.2071 - val_acc: 0.2391
# Epoch 7/50
# 31933/31933 [==============================] - 10s - loss: 2.2031 - acc: 0.2316 - val_loss: 2.2018 - val_acc: 0.2444
# Epoch 8/50
# 31933/31933 [==============================] - 11s - loss: 2.2459 - acc: 0.2050 - val_loss: 2.2941 - val_acc: 0.2371
# Epoch 9/50
# 31933/31933 [==============================] - 10s - loss: 2.3051 - acc: 0.1856 - val_loss: 2.2500 - val_acc: 0.2351
# Epoch 10/50
# 31933/31933 [==============================] - 11s - loss: 2.2473 - acc: 0.2212 - val_loss: 2.2281 - val_acc: 0.2407
# Epoch 11/50
# 31933/31933 [==============================] - 11s - loss: 2.2240 - acc: 0.2225 - val_loss: 2.1900 - val_acc: 0.2412
# Epoch 12/50
# 31933/31933 [==============================] - 10s - loss: 2.2201 - acc: 0.2232 - val_loss: 2.2037 - val_acc: 0.2411
# Epoch 13/50
# 31933/31933 [==============================] - 10s - loss: 2.2086 - acc: 0.2237 - val_loss: 2.2124 - val_acc: 0.2424
# Epoch 14/50
# 31933/31933 [==============================] - 10s - loss: 2.2068 - acc: 0.2238 - val_loss: 2.2119 - val_acc: 0.2397
# Epoch 15/50
# 31933/31933 [==============================] - 10s - loss: 2.2053 - acc: 0.2265 - val_loss: 2.1756 - val_acc: 0.2432
# Epoch 16/50
# 31933/31933 [==============================] - 10s - loss: 2.2120 - acc: 0.2254 - val_loss: 2.1945 - val_acc: 0.2411
# Epoch 17/50
# 31933/31933 [==============================] - 12s - loss: 2.1934 - acc: 0.2225 - val_loss: 2.1687 - val_acc: 0.2385
# Epoch 18/50
# 31933/31933 [==============================] - 11s - loss: 2.1927 - acc: 0.2276 - val_loss: 2.2039 - val_acc: 0.2391
# Epoch 19/50
# 31933/31933 [==============================] - 10s - loss: 2.1944 - acc: 0.2290 - val_loss: 2.2055 - val_acc: 0.2399
# Epoch 20/50
# 31933/31933 [==============================] - 10s - loss: 2.1858 - acc: 0.2282 - val_loss: 2.1634 - val_acc: 0.2445
# Epoch 21/50
# 31933/31933 [==============================] - 10s - loss: 2.1867 - acc: 0.2269 - val_loss: 2.1955 - val_acc: 0.2401
# Epoch 22/50
# 31933/31933 [==============================] - 10s - loss: 2.1860 - acc: 0.2303 - val_loss: 2.1999 - val_acc: 0.2401
# Epoch 23/50
# 31933/31933 [==============================] - 10s - loss: 2.1911 - acc: 0.2329 - val_loss: 2.2012 - val_acc: 0.2413
# Epoch 24/50
# 31933/31933 [==============================] - 10s - loss: 2.1814 - acc: 0.2339 - val_loss: 2.1982 - val_acc: 0.2434
# Epoch 25/50
# 31933/31933 [==============================] - 10s - loss: 2.1824 - acc: 0.2335 - val_loss: 2.1780 - val_acc: 0.2448
# Epoch 26/50
# 31933/31933 [==============================] - 10s - loss: 2.1722 - acc: 0.2350 - val_loss: 2.1560 - val_acc: 0.2443
# Epoch 27/50
# 31933/31933 [==============================] - 11s - loss: 2.1769 - acc: 0.2341 - val_loss: 2.1518 - val_acc: 0.2445
# Epoch 28/50
# 31933/31933 [==============================] - 11s - loss: 2.1676 - acc: 0.2365 - val_loss: 2.1475 - val_acc: 0.2460
# Epoch 29/50
# 31933/31933 [==============================] - 11s - loss: 2.1610 - acc: 0.2353 - val_loss: 2.1679 - val_acc: 0.2466
# Epoch 30/50
# 31933/31933 [==============================] - 11s - loss: 2.1688 - acc: 0.2371 - val_loss: 2.1433 - val_acc: 0.2465
# Epoch 31/50
# 31933/31933 [==============================] - 11s - loss: 2.1535 - acc: 0.2370 - val_loss: 2.1356 - val_acc: 0.2470
# Epoch 32/50
# 31933/31933 [==============================] - 11s - loss: 2.1605 - acc: 0.2344 - val_loss: 2.1808 - val_acc: 0.2428
# Epoch 33/50
# 31933/31933 [==============================] - 11s - loss: 2.1667 - acc: 0.2372 - val_loss: 2.1655 - val_acc: 0.2492
# Epoch 34/50
# 31933/31933 [==============================] - 10s - loss: 2.1709 - acc: 0.2418 - val_loss: 2.1574 - val_acc: 0.2496
# Epoch 35/50
# 31933/31933 [==============================] - 11s - loss: 2.1489 - acc: 0.2446 - val_loss: 2.1308 - val_acc: 0.2474
# Epoch 36/50
# 31933/31933 [==============================] - 11s - loss: 2.1590 - acc: 0.2443 - val_loss: 2.1497 - val_acc: 0.2519
# Epoch 37/50
# 31933/31933 [==============================] - 10s - loss: 2.1576 - acc: 0.2445 - val_loss: 2.1379 - val_acc: 0.2408
# Epoch 38/50
# 31933/31933 [==============================] - 10s - loss: 2.1629 - acc: 0.2419 - val_loss: 2.1292 - val_acc: 0.2492
# Epoch 39/50
# 31933/31933 [==============================] - 10s - loss: 2.1478 - acc: 0.2476 - val_loss: 2.1126 - val_acc: 0.2584
# Epoch 40/50
# 31933/31933 [==============================] - 10s - loss: 2.1332 - acc: 0.2521 - val_loss: 2.0985 - val_acc: 0.2632
# Epoch 41/50
# 31933/31933 [==============================] - 10s - loss: 2.2099 - acc: 0.2325 - val_loss: 2.1444 - val_acc: 0.2345
# Epoch 42/50
# 31933/31933 [==============================] - 10s - loss: 2.1721 - acc: 0.2378 - val_loss: 2.1399 - val_acc: 0.2481
# Epoch 43/50
# 31933/31933 [==============================] - 10s - loss: 2.1551 - acc: 0.2456 - val_loss: 2.1259 - val_acc: 0.2551
# Epoch 44/50
# 31933/31933 [==============================] - 10s - loss: 2.1432 - acc: 0.2486 - val_loss: 2.1138 - val_acc: 0.2580
# Epoch 45/50
# 31933/31933 [==============================] - 11s - loss: 2.1315 - acc: 0.2539 - val_loss: 2.1118 - val_acc: 0.2672
# Epoch 46/50
# 31933/31933 [==============================] - 11s - loss: 2.1192 - acc: 0.2632 - val_loss: 2.0828 - val_acc: 0.2804
# Epoch 47/50
# 31933/31933 [==============================] - 10s - loss: 2.1121 - acc: 0.2665 - val_loss: 2.0708 - val_acc: 0.2795
# Epoch 48/50
# 31933/31933 [==============================] - 10s - loss: 2.1067 - acc: 0.2710 - val_loss: 2.0748 - val_acc: 0.2841
# Epoch 49/50
# 31933/31933 [==============================] - 11s - loss: 2.1220 - acc: 0.2639 - val_loss: 2.0984 - val_acc: 0.2743
# Epoch 50/50
# 31933/31933 [==============================] - 10s - loss: 2.1344 - acc: 0.2591 - val_loss: 2.0945 - val_acc: 0.2760
# 31328/31933 [============================>.] - ETA: 0s
# acc: 27.60%

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_acc', 'val_loss', 'acc', 'loss'])

# %%
a = "i'm very happy"
