# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
import os
import numpy as np
from scipy import sparse
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
np.random.seed(1)

# %%
dataset = np.loadtxt("train_en.txt")
# split into input (X) and output (Y) variables
X = dataset[:,0:300]
Y = dataset[:,300]
Y = keras.utils.to_categorical(Y, num_classes=13)

test_data = np.loadtxt("test_en.txt")
# split into input (X) and output (Y) variables
X_test = dataset[:,0:300]
Y_test = dataset[:,300]
Y_test = keras.utils.to_categorical(Y_test, num_classes=13)

# %%
# create model
model = Sequential()
model.add(Dense(100, input_dim=300, activation='softmax'))
model.add(Dropout(0.5))
model.add(Dense(13, activation='softmax'))
# Compile model
model.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 13)                1313
# =================================================================
# Total params: 31,413
# Trainable params: 31,413
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model 
history = model.fit(X, Y, epochs=50, batch_size=10,
          validation_data=(X_test, Y_test))
# evaluate the model
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Train on 31933 samples, validate on 31933 samples
# Epoch 1/50
# 31933/31933 [==============================] - 11s - loss: 2.2532 - acc: 0.2121 - val_loss: 2.1767 - val_acc: 0.2108
# Epoch 2/50
# 31933/31933 [==============================] - 11s - loss: 2.1674 - acc: 0.2124 - val_loss: 2.1618 - val_acc: 0.2124
# Epoch 3/50
# 31933/31933 [==============================] - 11s - loss: 2.1597 - acc: 0.2139 - val_loss: 2.1574 - val_acc: 0.2167
# Epoch 4/50
# 31933/31933 [==============================] - 11s - loss: 2.1566 - acc: 0.2103 - val_loss: 2.1556 - val_acc: 0.2119
# Epoch 5/50
# 31933/31933 [==============================] - 11s - loss: 2.1552 - acc: 0.2139 - val_loss: 2.1544 - val_acc: 0.2125
# Epoch 6/50
# 31933/31933 [==============================] - 11s - loss: 2.1545 - acc: 0.2149 - val_loss: 2.1538 - val_acc: 0.2129
# Epoch 7/50
# 31933/31933 [==============================] - 11s - loss: 2.1539 - acc: 0.2105 - val_loss: 2.1533 - val_acc: 0.2125
# Epoch 8/50
# 31933/31933 [==============================] - 11s - loss: 2.1536 - acc: 0.2122 - val_loss: 2.1530 - val_acc: 0.2118
# Epoch 9/50
# 31933/31933 [==============================] - 11s - loss: 2.1531 - acc: 0.2134 - val_loss: 2.1530 - val_acc: 0.2108
# Epoch 10/50
# 31933/31933 [==============================] - 11s - loss: 2.1530 - acc: 0.2143 - val_loss: 2.1526 - val_acc: 0.2124
# Epoch 11/50
# 31933/31933 [==============================] - 11s - loss: 2.1530 - acc: 0.2145 - val_loss: 2.1525 - val_acc: 0.2118
# Epoch 12/50
# 31933/31933 [==============================] - 11s - loss: 2.1529 - acc: 0.2143 - val_loss: 2.1523 - val_acc: 0.2307
# Epoch 13/50
# 31933/31933 [==============================] - 11s - loss: 2.1527 - acc: 0.2144 - val_loss: 2.1522 - val_acc: 0.2245
# Epoch 14/50
# 31933/31933 [==============================] - 11s - loss: 2.1525 - acc: 0.2191 - val_loss: 2.1523 - val_acc: 0.2111
# Epoch 15/50
# 31933/31933 [==============================] - 11s - loss: 2.1524 - acc: 0.2162 - val_loss: 2.1521 - val_acc: 0.2125
# Epoch 16/50
# 31933/31933 [==============================] - 11s - loss: 2.1525 - acc: 0.2153 - val_loss: 2.1520 - val_acc: 0.2399
# Epoch 17/50
# 31933/31933 [==============================] - 11s - loss: 2.1523 - acc: 0.2155 - val_loss: 2.1520 - val_acc: 0.2112
# Epoch 18/50
# 31933/31933 [==============================] - 11s - loss: 2.1522 - acc: 0.2141 - val_loss: 2.1520 - val_acc: 0.2377
# Epoch 19/50
# 31933/31933 [==============================] - 11s - loss: 2.1521 - acc: 0.2210 - val_loss: 2.1522 - val_acc: 0.2125
# Epoch 20/50
# 31933/31933 [==============================] - 11s - loss: 2.1521 - acc: 0.2165 - val_loss: 2.1519 - val_acc: 0.2125
# Epoch 21/50
# 31933/31933 [==============================] - 11s - loss: 2.1520 - acc: 0.2190 - val_loss: 2.1517 - val_acc: 0.2123
# Epoch 22/50
# 31933/31933 [==============================] - 11s - loss: 2.1521 - acc: 0.2173 - val_loss: 2.1517 - val_acc: 0.2134
# Epoch 23/50
# 31933/31933 [==============================] - 11s - loss: 2.1518 - acc: 0.2183 - val_loss: 2.1517 - val_acc: 0.2185
# Epoch 24/50
# 31933/31933 [==============================] - 11s - loss: 2.1519 - acc: 0.2201 - val_loss: 2.1515 - val_acc: 0.2131
# Epoch 25/50
# 31933/31933 [==============================] - 11s - loss: 2.1518 - acc: 0.2187 - val_loss: 2.1515 - val_acc: 0.2310
# Epoch 26/50
# 31933/31933 [==============================] - 11s - loss: 2.1518 - acc: 0.2196 - val_loss: 2.1514 - val_acc: 0.2155
# Epoch 27/50
# 31933/31933 [==============================] - 11s - loss: 2.1516 - acc: 0.2197 - val_loss: 2.1513 - val_acc: 0.2255
# Epoch 28/50
# 31933/31933 [==============================] - 12s - loss: 2.1514 - acc: 0.2195 - val_loss: 2.1511 - val_acc: 0.2128
# Epoch 29/50
# 31933/31933 [==============================] - 11s - loss: 2.1512 - acc: 0.2203 - val_loss: 2.1511 - val_acc: 0.2124
# Epoch 30/50
# 31933/31933 [==============================] - 11s - loss: 2.1513 - acc: 0.2234 - val_loss: 2.1508 - val_acc: 0.2282
# Epoch 31/50
# 31933/31933 [==============================] - 10s - loss: 2.1511 - acc: 0.2210 - val_loss: 2.1506 - val_acc: 0.2321
# Epoch 32/50
# 31933/31933 [==============================] - 12s - loss: 2.1510 - acc: 0.2222 - val_loss: 2.1504 - val_acc: 0.2406
# Epoch 33/50
# 31933/31933 [==============================] - 11s - loss: 2.1506 - acc: 0.2246 - val_loss: 2.1500 - val_acc: 0.2132
# Epoch 34/50
# 31933/31933 [==============================] - 11s - loss: 2.1497 - acc: 0.2224 - val_loss: 2.1489 - val_acc: 0.2219
# Epoch 35/50
# 31933/31933 [==============================] - 11s - loss: 2.1496 - acc: 0.2247 - val_loss: 2.1482 - val_acc: 0.2164
# Epoch 36/50
# 31933/31933 [==============================] - 11s - loss: 2.1493 - acc: 0.2261 - val_loss: 2.1471 - val_acc: 0.2268
# Epoch 37/50
# 31933/31933 [==============================] - 11s - loss: 2.1485 - acc: 0.2241 - val_loss: 2.1461 - val_acc: 0.2395
# Epoch 38/50
# 31933/31933 [==============================] - 10s - loss: 2.1478 - acc: 0.2244 - val_loss: 2.1451 - val_acc: 0.2356
# Epoch 39/50
# 31933/31933 [==============================] - 10s - loss: 2.1475 - acc: 0.2238 - val_loss: 2.1443 - val_acc: 0.2397
# Epoch 40/50
# 31933/31933 [==============================] - 10s - loss: 2.1471 - acc: 0.2232 - val_loss: 2.1435 - val_acc: 0.2405
# Epoch 41/50
# 31933/31933 [==============================] - 10s - loss: 2.1462 - acc: 0.2257 - val_loss: 2.1421 - val_acc: 0.2425
# Epoch 42/50
# 31933/31933 [==============================] - 10s - loss: 2.1458 - acc: 0.2245 - val_loss: 2.1411 - val_acc: 0.2456
# Epoch 43/50
# 31933/31933 [==============================] - 10s - loss: 2.1451 - acc: 0.2255 - val_loss: 2.1404 - val_acc: 0.2377
# Epoch 44/50
# 31933/31933 [==============================] - 10s - loss: 2.1445 - acc: 0.2247 - val_loss: 2.1389 - val_acc: 0.2479
# Epoch 45/50
# 31933/31933 [==============================] - 10s - loss: 2.1430 - acc: 0.2285 - val_loss: 2.1372 - val_acc: 0.2432
# Epoch 46/50
# 31933/31933 [==============================] - 10s - loss: 2.1430 - acc: 0.2271 - val_loss: 2.1364 - val_acc: 0.2404
# Epoch 47/50
# 31933/31933 [==============================] - 10s - loss: 2.1411 - acc: 0.2290 - val_loss: 2.1350 - val_acc: 0.2494
# Epoch 48/50
# 31933/31933 [==============================] - 11s - loss: 2.1403 - acc: 0.2264 - val_loss: 2.1343 - val_acc: 0.2361
# Epoch 49/50
# 31933/31933 [==============================] - 11s - loss: 2.1390 - acc: 0.2275 - val_loss: 2.1323 - val_acc: 0.2379
# Epoch 50/50
# 31933/31933 [==============================] - 11s - loss: 2.1378 - acc: 0.2305 - val_loss: 2.1302 - val_acc: 0.2482
# 31040/31933 [============================>.] - ETA: 0s
# acc: 24.82%

# %%
print(history.history.keys())
#  "Accuracy"
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_acc', 'val_loss', 'acc', 'loss'])
